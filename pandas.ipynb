# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul-Muqtadir/machine-learning/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]}, index=["Yes","No"])
# Out:
#      Yes   No
# Yes   50  131
# No    21    2

# %%
pd.DataFrame({'bob':['i am abishola', 'i am not abishola'], 'abishola':['i am bob','i am not bob']})

# %%
pd.DataFrame({'bob':['i am abishola','i am not abishola'],'abishola':['i am bob','i am not bob']}, index = ['bob john','abishola bob'])
# Out:
#                             bob      abishola
# bob john          i am abishola      i am bob
# abishola bob  i am not abishola  i am not bob

# %%
pd.Series(['1','2','3','4'])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: object

# %%
pd.Series(['1','2','3','4'], index = ['One','Two','Three','Four'],name = 'counting')
# Out:
# One      1
# Two      2
# Three    3
# Four     4
# Name: counting, dtype: object

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd '/content/drive/MyDrive/kaggle/'
# !mkdir ~/.kaggle
# !cp /content/drive/MyDrive/kaggle/kaggle.json -r ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d christopheiv/winemagdata130k
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/kaggle
# winemagdata130k.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip {"/content/drive/MyDrive/kaggle/winemagdata130k.zip"} -d data
# Out:
# Archive:  /content/drive/MyDrive/kaggle/winemagdata130k.zip
# replace data/winemag-data-130k-v2.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/winemag-data-130k-v2.csv
# replace data/winemag-data-130k-v2.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: data/winemag-data-130k-v2.json

# %%
wine_reviews=pd.read_csv('/content/drive/MyDrive/kaggle/data/winemag-data-130k-v2.csv')

# %%
wine_reviews.shape
# Out:
# (129971, 14)

# %%
wine_reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
wine_reviews.rename(columns={'points':'score'})
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
wine_reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
wine_reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields  Unnamed: 0   country  \
# wines
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
# fields                                        description  \
# wines
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...
